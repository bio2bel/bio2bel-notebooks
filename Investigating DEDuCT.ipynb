# %% [markdown]
# This notebook outlines some basic analysis of the terms used in the [DEDuCT](https://cb.imsc.res.in/deduct/) database. Some terms have been used that represent directed relationships with biomarkers, clinical endpoints, abundances of biological entities, activities of biological entities, ratios of biological entities, and others.
#
# [Gilda](https://github.com/indralab/gilda) was used to look up normalizations on a first pass, but it lacks entries from Disease Ontology, Experimental Factor Ontology, and Human Phenotype Ontology that would likely be most appropriate. This notebook will later be appended with other results from the [EBI Ontology Lookup Service](https://www.ebi.ac.uk/ols/index) which could provide complementary results.

# %%
import json
from collections import Counter

import requests
import pandas as pd
from tqdm import tqdm_notebook as tqdm

# %%
GILDA_URL = 'http://34.201.164.108:8001'

def post_gilda(text: str, url: str = GILDA_URL) -> requests.Response:
    """Send text to GILDA."""
    return requests.post(f'{url}/ground', json={'text': text})

# %% [markdown]
# ## Data

# %%
chemicals_url = 'https://cb.imsc.res.in/deduct/images/Batch_Download/DEDuCT_ChemicalBasicInformation.csv'
chemicals_df = pd.read_csv(chemicals_url, index_col=0)

# %%
evidences_url = 'https://cb.imsc.res.in/deduct/images/Batch_Download/DEDuCT_ExperimentalEvidence.csv'
evidences_df = pd.read_csv(evidences_url, index_col=0)
del evidences_df['Name']

# %%
df = evidences_df.join(chemicals_df)
df = df[df['PubChem identifier'].notna()]
df.head()
# Out:
#                    Literature identifier Study type Dosage unit  \
# Primary identifier
# CAS:319-85-7                PMID:2423406        IVR       mg/kg
# CAS:319-85-7                PMID:2423406        IVR       mg/kg
# CAS:319-85-7                PMID:2423406        IVR       mg/kg
# CAS:319-85-7                PMID:2423406        IVR       mg/kg
# CAS:319-85-7                PMID:2423406        IVR       mg/kg
#
#                     Tested concentration – Lower  \
# Primary identifier
# CAS:319-85-7                               250.0
# CAS:319-85-7                               250.0
# CAS:319-85-7                               250.0
# CAS:319-85-7                                50.0
# CAS:319-85-7                                10.0
#
#                     Tested concentration – Upper  \
# Primary identifier
# CAS:319-85-7                               250.0
# CAS:319-85-7                               250.0
# CAS:319-85-7                               250.0
# CAS:319-85-7                                50.0
# CAS:319-85-7                                10.0
#
#                     Effective concentration – Lower  \
# Primary identifier
# CAS:319-85-7                                  250.0
# CAS:319-85-7                                  250.0
# CAS:319-85-7                                  250.0
# CAS:319-85-7                                   50.0
# CAS:319-85-7                                   10.0
#
#                     Effective concentration – Upper  \
# Primary identifier
# CAS:319-85-7                                    NaN
# CAS:319-85-7                                    NaN
# CAS:319-85-7                                    NaN
# CAS:319-85-7                                    NaN
# CAS:319-85-7                                    NaN
#
#                       Endocrine-mediated endpoints  \
# Primary identifier
# CAS:319-85-7               Affects spermatogenesis
# CAS:319-85-7             Decreased ovarian weights
# CAS:319-85-7        Decreased thymus gland weights
# CAS:319-85-7               Increased liver weights
# CAS:319-85-7             Increased ovarian weights
#
#                                         Endocrine mediated systems CAS Number  \
# Primary identifier
# CAS:319-85-7         Reproductive endocrine-mediated perturbations   319-85-7
# CAS:319-85-7         Reproductive endocrine-mediated perturbations   319-85-7
# CAS:319-85-7        Immunological endocrine-mediated perturbations   319-85-7
# CAS:319-85-7              Hepatic endocrine-mediated perturbations   319-85-7
# CAS:319-85-7         Reproductive endocrine-mediated perturbations   319-85-7
#
#                     PubChem identifier                        Name  \
# Primary identifier
# CAS:319-85-7                     727.0  beta-Hexachlorocyclohexane
# CAS:319-85-7                     727.0  beta-Hexachlorocyclohexane
# CAS:319-85-7                     727.0  beta-Hexachlorocyclohexane
# CAS:319-85-7                     727.0  beta-Hexachlorocyclohexane
# CAS:319-85-7                     727.0  beta-Hexachlorocyclohexane
#
#                                            IUPAC_Name  \
# Primary identifier
# CAS:319-85-7        1,2,3,4,5,6-hexachlorocyclohexane
# CAS:319-85-7        1,2,3,4,5,6-hexachlorocyclohexane
# CAS:319-85-7        1,2,3,4,5,6-hexachlorocyclohexane
# CAS:319-85-7        1,2,3,4,5,6-hexachlorocyclohexane
# CAS:319-85-7        1,2,3,4,5,6-hexachlorocyclohexane
#
#                                 SMILES (Canonical)  \
# Primary identifier
# CAS:319-85-7        C1(C(C(C(C(C1Cl)Cl)Cl)Cl)Cl)Cl
# CAS:319-85-7        C1(C(C(C(C(C1Cl)Cl)Cl)Cl)Cl)Cl
# CAS:319-85-7        C1(C(C(C(C(C1Cl)Cl)Cl)Cl)Cl)Cl
# CAS:319-85-7        C1(C(C(C(C(C1Cl)Cl)Cl)Cl)Cl)Cl
# CAS:319-85-7        C1(C(C(C(C(C1Cl)Cl)Cl)Cl)Cl)Cl
#
#                                                                 INCHI  \
# Primary identifier
# CAS:319-85-7        InChI=1S/C6H6Cl6/c7-1-2(8)4(10)6(12)5(11)3(1)9...
# CAS:319-85-7        InChI=1S/C6H6Cl6/c7-1-2(8)4(10)6(12)5(11)3(1)9...
# CAS:319-85-7        InChI=1S/C6H6Cl6/c7-1-2(8)4(10)6(12)5(11)3(1)9...
# CAS:319-85-7        InChI=1S/C6H6Cl6/c7-1-2(8)4(10)6(12)5(11)3(1)9...
# CAS:319-85-7        InChI=1S/C6H6Cl6/c7-1-2(8)4(10)6(12)5(11)3(1)9...
#
#                                       INCHI_Key
# Primary identifier
# CAS:319-85-7        JLYXXMFPNIAWKQ-CDRYSYESSA-N
# CAS:319-85-7        JLYXXMFPNIAWKQ-CDRYSYESSA-N
# CAS:319-85-7        JLYXXMFPNIAWKQ-CDRYSYESSA-N
# CAS:319-85-7        JLYXXMFPNIAWKQ-CDRYSYESSA-N
# CAS:319-85-7        JLYXXMFPNIAWKQ-CDRYSYESSA-N

# %% [markdown]
# ## Normalizing terms containing relationships
#
# The set of endpoints contains several common prefixes and suffixes. The prefixes usually correspond to relationship types and the suffixes usually denote that the abundance of the target of the relationship is being measured.

# %%
# This dictionary maps different forms of the same relationship
relationships = {
    'Affects': 'affect',
    'Decreased': 'decrease',
    'Increased': 'increase',
    'Changes': 'change',
    'Decrease': 'decrease',
    'Induced': 'increase',
    'Increase': 'increase',
    'Elevated': 'increase',
    'Reduced': 'decrease',
    'Causes': 'affect',
    'Induce': 'increase',
    'Impaired': 'decrease',
    'Altered': 'change',
    'Accumulation': 'increase',
    'Alteration': 'change',
}

# %%
def get_prefix(endpoint):
    for relationship in relationships:
        for prefix in ('in', 'of'):
            if endpoint.startswith(f'{relationship} {prefix}'):
                return relationship, prefix
        if endpoint.startswith(relationship):
            return relationship, ''
    return None, None


def get_suffix(endpoint):
    if endpoint.endswith('levels'):
        return 'levels'
    return ''
    
    
unnormalized_df_rows = []
normalized_df_rows = []
for endpoint in df['Endocrine-mediated endpoints'].unique():
    relationship, prefix = get_prefix(endpoint)
    suffix = get_suffix(endpoint)
    if relationship:
        prefix_length = len(f'{relationship} {prefix}')
        if suffix:
            term = endpoint[prefix_length:-len(suffix)]
        else:
            term = endpoint[prefix_length:]
            
        normalized_df_rows.append((
            relationships[relationship], 
            term.lstrip(),
            endpoint,
        ))
    else:
        unnormalized_df_rows.append(endpoint)

normalized_df = pd.DataFrame(
    normalized_df_rows, 
    columns=['relationship', 'term', 'endpoint'],
)
normalized_df
# Out:
#     relationship                                      term  \
# 0         affect                           spermatogenesis
# 1       decrease                           ovarian weights
# 2       decrease                      thymus gland weights
# 3       increase                             liver weights
# 4       increase                           ovarian weights
# 5       increase                           uterine weights
# 6       increase                  weights of adrenal gland
# 7       increase                weights of pituitary gland
# 8         affect                         calcium signaling
# 9         affect                          folliculogenesis
# 10        affect                                 ovulation
# 11        affect                        steroid metabolism
# 12        affect                           steroidogenesis
# 13        affect                   testosterone metabolism
# 14        affect                     xenobiotic metabolism
# 15        change                   in preputial separation
# 16        change                        in vaginal opening
# 17        change                  adrenal gland morphology
# 18        change                          liver morphology
# 19        change             liver morphology in offspring
# 20      decrease                                 cortisol
# 21      decrease                                       T3
# 22      decrease                                       T4
# 23      decrease                            spleen weights
# 24      decrease   weights of pituitary gland in offspring
# 25      increase                                       T4
# 26      increase                liver weights in offspring
# 27      increase       migration capability of tumor cells
# 28      decrease                       17-OH-progesterone
# 29      decrease                          androstenedione
# ..           ...                                       ...
# 374     increase          epididymal vesicles in offspring
# 375     increase                                   leptin
# 376     increase                   apoptosis of beta cells
# 377     decrease         thymus gland weights in offspring
# 378     increase                                  hibin-B
# 379     decrease              uterine weights in offspring
# 380     decrease     weights of adrenal gland in offspring
# 381     decrease     weights of thyroid gland in offspring
# 382     increase  weights of seminal vesicles in offspring
# 383       change                            DOPAC/DA ratio
# 384       change                     germ cells morphology
# 385       affect     the biochemical composition of uterus
# 386     increase                      vas deferens weights
# 387     decrease                               T3/T4 ratio
# 388     increase                                  calcium
# 389       affect                       androgen production
# 390       affect                     leydig cells function
# 391       affect                      pancreas development
# 392     decrease              estradiol/progesterone ratio
# 393     decrease                    LH levels in offspring
# 394       affect                      vitamin D metabolism
# 395     decrease                               T4/T3 ratio
# 396     increase               Alkaline phosphatase (ALP)
# 397       change                         spleen morphology
# 398     decrease                   FSH levels in offspring
# 399     decrease             prolactin levels in offspring
# 400       affect                  electron transport chain
# 401     decrease         Aspartate aminotransferase (AST)
# 402     increase                         bilurubin content
# 403     decrease              ovarian weights in offspring
#
#                                               endpoint
# 0                              Affects spermatogenesis
# 1                            Decreased ovarian weights
# 2                       Decreased thymus gland weights
# 3                              Increased liver weights
# 4                            Increased ovarian weights
# 5                            Increased uterine weights
# 6                   Increased weights of adrenal gland
# 7                 Increased weights of pituitary gland
# 8                            Affects calcium signaling
# 9                             Affects folliculogenesis
# 10                                   Affects ovulation
# 11                          Affects steroid metabolism
# 12                             Affects steroidogenesis
# 13                     Affects testosterone metabolism
# 14                       Affects xenobiotic metabolism
# 15                 Alterations in preputial separation
# 16                      Alterations in vaginal opening
# 17                 Changes in adrenal gland morphology
# 18                         Changes in liver morphology
# 19            Changes in liver morphology in offspring
# 20                         Decrease in cortisol levels
# 21                               Decrease in T3 levels
# 22                               Decrease in T4 levels
# 23                            Decreased spleen weights
# 24   Decreased weights of pituitary gland in offspring
# 25                               Increase in T4 levels
# 26                Increased liver weights in offspring
# 27         Induced migration capability of tumor cells
# 28                 Decreased 17-OH-progesterone levels
# 29                    Decreased androstenedione levels
# ..                                                 ...
# 374         Increased epididymal vesicles in offspring
# 375                            Increased leptin levels
# 376                     Induce apoptosis of beta cells
# 377        Decreased thymus gland weights in offspring
# 378                         Increased inhibin-B levels
# 379             Decreased uterine weights in offspring
# 380    Decreased weights of adrenal gland in offspring
# 381    Decreased weights of thyroid gland in offspring
# 382  Increased weights of seminal vesicles in offsp...
# 383                             Altered DOPAC/DA ratio
# 384                      Altered germ cells morphology
# 385      Affects the biochemical composition of uterus
# 386                     Increased vas deferens weights
# 387                            Decrease in T3/T4 ratio
# 388                           Increased calcium levels
# 389                        Affects androgen production
# 390                      Affects leydig cells function
# 391                       Affects pancreas development
# 392             Decreased estradiol/progesterone ratio
# 393                   Decreased LH levels in offspring
# 394                       Affects vitamin D metabolism
# 395                            Decrease in T4/T3 ratio
# 396        Increased Alkaline phosphatase (ALP) levels
# 397                       Changes in spleen morphology
# 398                  Decreased FSH levels in offspring
# 399            Decreased prolactin levels in offspring
# 400                   Affects electron transport chain
# 401  Decreased Aspartate aminotransferase (AST) levels
# 402                        Increased bilurubin content
# 403             Decreased ovarian weights in offspring
#
# [404 rows x 3 columns]

# %%
gilda_normalized_df_rows = []

it = tqdm(set(normalized_df.term), desc='Querying Gilda')
for term in it:
    res_json = post_gilda(term).json()
    if not res_json:
        continue
    for result in res_json:
        gilda_normalized_df_row = (
            term, round(result['score'], 3), result['term']['db'].lower(),
            result['term']['id'], result['term']['entry_name'] 
        )
        gilda_normalized_df_rows.append(gilda_normalized_df_row)
# Out:
# HBox(children=(IntProgress(value=0, description='Querting Gilda', max=324, style=ProgressStyle(description_wid…

# %%
gilda_normalized_df = pd.DataFrame(
    gilda_normalized_df_rows,
    columns=['query', 'gilda_score', 'db', 'db_id', 'db_name']
)
gilda_normalized_df
# Out:
#                             query  gilda_score    db       db_id  \
# 0           developmental process        0.778    go  GO:0032502
# 1                 social behavior        0.778    go  GO:0035176
# 2                 social behavior        0.762  mesh     D012919
# 3                       fertility        0.762  mesh     D005298
# 4                  glycogenolysis        0.762  mesh     D050261
# 5                       ovulation        0.778    go  GO:0030728
# 6                       ovulation        0.762  mesh     D010060
# 7                        lordosis        0.762  mesh     D008141
# 8                  sperm motility        0.778    go  GO:0097722
# 9                  sperm motility        0.762  mesh     D013081
# 10                  gametogenesis        0.762  mesh     D005718
# 11  acetylcholinesterase activity        0.778    go  GO:0003990
# 12          cholesterol transport        0.778    go  GO:0030301
# 13                gluconeogenesis        0.778    go  GO:0006094
# 14                gluconeogenesis        0.762  mesh     D005943
# 15             locomotor activity        0.540  mesh     D008124
# 16              calcium signaling        0.762  mesh     D020013
# 17                spermatogenesis        0.778    go  GO:0007283
# 18                spermatogenesis        0.762  mesh     D013091
# 19               spatial learning        0.762  mesh     D065853
# 20          embryonic development        0.762  mesh     D047108
# 21         epididymis development        0.778    go  GO:1905867
# 22               lipid metabolism        0.762  mesh     D050356
# 23          placental development        0.540  mesh     D010929
# 24                   sperm counts        0.540  mesh     D013076
# 25           xenobiotic transport        0.778    go  GO:0042908
# 26                 GABA-receptors        0.985  fplx        GABR
# 27                 GABA-receptors        0.540  mesh     D018079
# 28            uterine contraction        0.762  mesh     D014590
# 29       electron transport chain        0.778    go  GO:0022900
# 30                      lactation        0.778    go  GO:0007595
# 31                      lactation        0.762  mesh     D007774
# 32           pancreas development        0.778    go  GO:0031016
# 33    pituitary gland development        0.778    go  GO:0021983
# 34                 spatial memory        0.762  mesh     D065852
# 35                sexual behavior        0.762  mesh     D012725
# 36                    litter size        0.762  mesh     D008098
# 37      oxidative phosphorylation        0.778    go  GO:0006119
# 38      oxidative phosphorylation        0.762  mesh     D010085
# 39          Wnt signaling pathway        0.778    go  GO:0016055
# 40          Wnt signaling pathway        0.772  mesh     D060449
#
#                           db_name
# 0           developmental process
# 1                 social behavior
# 2                 Social Behavior
# 3                       Fertility
# 4                  Glycogenolysis
# 5                       ovulation
# 6                       Ovulation
# 7                        Lordosis
# 8                  sperm motility
# 9                  Sperm Motility
# 10                  Gametogenesis
# 11  acetylcholinesterase activity
# 12          cholesterol transport
# 13                gluconeogenesis
# 14                Gluconeogenesis
# 15                     Locomotion
# 16              Calcium Signaling
# 17                spermatogenesis
# 18                Spermatogenesis
# 19               Spatial Learning
# 20          Embryonic Development
# 21         epididymis development
# 22               Lipid Metabolism
# 23                   Placentation
# 24                    Sperm Count
# 25           xenobiotic transport
# 26                           GABR
# 27                Receptors, GABA
# 28            Uterine Contraction
# 29       electron transport chain
# 30                      lactation
# 31                      Lactation
# 32           pancreas development
# 33    pituitary gland development
# 34                 Spatial Memory
# 35                Sexual Behavior
# 36                    Litter Size
# 37      oxidative phosphorylation
# 38      Oxidative Phosphorylation
# 39          Wnt signaling pathway
# 40          Wnt Signaling Pathway

# %% [markdown]
# ## Normalizing terms without relationships
#
# The same technique was used for entities without relationships.

# %%
gilda_unnormalized_df_rows = []
for term in tqdm(unnormalized_df_rows, desc='Querying Gilda'):
    res_json = post_gilda(term).json()
    if not res_json:
        continue
    for result in res_json:
        gilda_unnormalized_df_row = (
            term, round(result['score'], 3), result['term']['db'].lower(),
            result['term']['id'], result['term']['entry_name'] 
        )
        gilda_unnormalized_df_rows.append(gilda_unnormalized_df_row)
# Out:
# HBox(children=(IntProgress(value=0, max=111), HTML(value='')))

# %%
gilda_normalized_df = pd.DataFrame(
    gilda_unnormalized_df_rows,
    columns=['query', 'gilda_score', 'db', 'db_id', 'db_name']
)
gilda_normalized_df
# Out:
#                        query  gilda_score    db    db_id  \
# 0    Pregnancy complications        0.772  mesh  D011248
# 1            Delayed puberty        0.549  mesh  D011628
# 2             Adenocarcinoma        0.778  mesh  D000230
# 3                  Paralysis        0.778  mesh  D010243
# 4       Erectile dysfunction        0.772  mesh  D007172
# 5         Follicular atresia        0.772  mesh  D005496
# 6    Endometrial hyperplasia        0.772  mesh  D004714
# 7       Cognitive impairment        0.549  mesh  D060825
# 8                Hypospadias        0.778  mesh  D007021
# 9   Hepatocellular carcinoma        0.549  mesh  D006528
# 10              Anophthalmia        0.556  mesh  D000853
#
#                       db_name
# 0     Pregnancy Complications
# 1            Puberty, Delayed
# 2              Adenocarcinoma
# 3                   Paralysis
# 4        Erectile Dysfunction
# 5          Follicular Atresia
# 6     Endometrial Hyperplasia
# 7       Cognitive Dysfunction
# 8                 Hypospadias
# 9   Carcinoma, Hepatocellular
# 10               Anophthalmos
